# %%
import time
import extract

from delta_load import run_delta_load


# ==========================
# Delta Load Process
# ==========================

# Gunakan file delta_load.csv
extract.set_mode("delta")


# Mulai hitung waktu
start = time.perf_counter()


# Run Delta Load
run_delta_load()


# Selesai
end = time.perf_counter()


print("=" * 50)
print("DELTA LOAD COMPLETED")
print(f"Execution Time : {end - start:.2f} seconds")
print("=" * 50)
# Out:
# Starting Delta Load...
# Last sales_date in fact_sales: 2018-05-09 23:58:16.010000
# Reading file : data/delta_load.csv
# Extracted 19424 rows.
# No new data to load.
# ...
# DELTA LOAD COMPLETED
# Execution Time : 0.23 seconds
# ...
